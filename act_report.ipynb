# %% [markdown]
# # Data Analysis of Twitter Data for WeRateDogs

# %% [markdown]
# ### Introduction

# %% [markdown]
# WeRateDogs has over 9 million followers as of November 2021 showing that there is a large potential userbase for followers of this type of material. This twitter account tweets images and gifs of dogs giving them scores, often at least 10/10, because as the viral meme says "They’re good dogs, Brent”.
#
# To analyse the data from this twitter account we would need to download the useful information and then analyse the results. However, unfortunately, data rarely comes in a clean state and so we would be using various techniques to clean and coimpile this information. The process of gathering, assessing and cleaning this data is called "Data Wrangling". The sources we would use for this would range from archives in spreadsheet format to pulling data directly from Twitter itself using something called an API.
#
# Once we had this information the question was, what can we do with the data we have tidied up for analysis? Well a great range of things so it would be up to us to narrow down exactly what we decide to do.

# %% [markdown]
# ### How Do We Rate?

# %% [markdown]
# Well it can be hard to tell how the ratings tend to go for this twitter account due to the massive amount of randomness when it comes to the denominators used, while many stick to keeping 10 for the rating denominator there is no way for a twitter account to standardise this so a great variety in denominators is seen. So to tackle this problem we simply came up with a new rating method by converting the denominator and numenator into a new single value.
#
# Doing this let us see from 0 to 1.5 what sort of ratings tend to be given.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As we can see most people like to give a rating score of at least 1 (or 10/10) with over 3/4's of people giving a score of at least 1!
#
# In retrospect not very surprising. Afterall the internet loves its pictures of doggos!

# %% [markdown]
# ### What Type Of Dog Is Most Popular?

# %% [markdown]
# Or more accurately put, what breed of dog do twitter users prefer? This is very simple for us to check.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It's easy for us to see that Golden Retrievers are in the lead by a significant margin! Followed closely by Labrador Retrievers. When I looked more closely at the pictures people tend to favorite or retweet more both of these breeds retained their respective positions as first and second most popular!
#
# Strangely though it was the Saluki sighthound that had the highest average score when it came to ratings!

# %% [markdown]
# ### Most Popular Way To Tweet!

# %% [markdown]
# A small departure from looking at just the dog data we are also able to look at HOW people interacted with the WeRateDogs twitter account.
#
# Perhaps not surprisingly the most common way users retweeted and favorited their most enjoyed dog tweets was from an iPhone, over 9 out of 10 users interacted with the twitter account in this way!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Does High Ratings = Popular?

# %% [markdown]
# In short? Yes!
#
# We where able to see from a quick look that, in general, the higher the rating the more likely a tweets would be retweeted or favoured a greater number of times!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is true both for Favouriting and Retweeting it would seem! So if you want the best chance at a doggo being popular then hope he gets a 13/10 as 1.3 seems to be the winning number!

# %% [markdown]
# ### After All Is Said & Done...

# %% [markdown]
# I think we can safely say that the internet just love their dogs!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#### Convert to html
# !jupyter nbconvert --to html act_report.ipynb
# Out:
# [NbConvertApp] Converting notebook act_report.ipynb to html
# [NbConvertApp] Writing 346890 bytes to act_report.html
